# %% [markdown]
# ## **WEATHER PREDICTION** ##

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Weather Data.csv')
df.head()
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
# 2  1/1/2012 2:00    -1.8              -3.4         89                7
# 3  1/1/2012 3:00    -1.5              -3.2         88                6
# 4  1/1/2012 4:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
df.tail()
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
#       Visibility_km  Press_kPa Weather
# 8779            9.7     100.13    Snow
# 8780            9.7     100.03    Snow
# 8781            4.8      99.95    Snow
# 8782            9.7      99.91    Snow
# 8783           11.3      99.89    Snow

# %% [markdown]
# ## EDA ##

# %%
df.shape
# Out:
# (8784, 8)

# %%
df.columns
# Out:
# Index(['Date/Time', 'Temp_C', 'Dew Point Temp_C', 'Rel Hum_%',
#        'Wind Speed_km/h', 'Visibility_km', 'Press_kPa', 'Weather'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date/Time         8784 non-null   object
#  1   Temp_C            8784 non-null   float64
#  2   Dew Point Temp_C  8784 non-null   float64
#  3   Rel Hum_%         8784 non-null   int64
#  4   Wind Speed_km/h   8784 non-null   int64
#  5   Visibility_km     8784 non-null   float64
#  6   Press_kPa         8784 non-null   float64
#  7   Weather           8784 non-null   object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 549.1+ KB

# %%
df.size
# Out:
# 70272

# %%
df.nunique()
# Out:
# Date/Time           8784
# Temp_C               533
# Dew Point Temp_C     489
# Rel Hum_%             83
# Wind Speed_km/h       34
# Visibility_km         24
# Press_kPa            518
# Weather               50
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Date/Time           0
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_km/h     0
# Visibility_km       0
# Press_kPa           0
# Weather             0
# dtype: int64

# %%
df.describe()
# Out:
#             Temp_C  Dew Point Temp_C    Rel Hum_%  Wind Speed_km/h  \
# count  8784.000000       8784.000000  8784.000000      8784.000000
# mean      8.798144          2.555294    67.431694        14.945469
# std      11.687883         10.883072    16.918881         8.688696
# min     -23.300000        -28.500000    18.000000         0.000000
# 25%       0.100000         -5.900000    56.000000         9.000000
# 50%       9.300000          3.300000    68.000000        13.000000
# 75%      18.800000         11.800000    81.000000        20.000000
# max      33.000000         24.400000   100.000000        83.000000
#
#        Visibility_km    Press_kPa
# count    8784.000000  8784.000000
# mean       27.664447   101.051623
# std        12.622688     0.844005
# min         0.200000    97.520000
# 25%        24.100000   100.560000
# 50%        25.000000   101.070000
# 75%        25.000000   101.590000
# max        48.300000   103.650000

# %% [markdown]
# ## VISUALIZATION ##

# %%
sns.set(rc = {'figure.figsize':(15,10)})
sns.barplot(y=df['Weather'].value_counts().index,x=df['Weather'].value_counts())
# Out:
# <AxesSubplot:xlabel='Weather'>

# %% [markdown]
# The graph shows the count of each class in the weather column of the dataset. According to this graph the weather of the area is Mainly Clear.

# %%
sns.displot(df['Temp_C'],kde=True)

# %% [markdown]
# The above displayed graph is of count of Temperature. The graph shows the result that temperature of dataset's region mostly remaiins between -5C to 25C.

# %%
sns.set(rc = {'figure.figsize':(13,9)})
sns.lineplot(x=df['Temp_C'],y=df['Rel Hum_%']).set(title='HUMIDITY VS TEMPERATURE')
# Out:
# [Text(0.5, 1.0, 'HUMIDITY VS TEMPERATURE')]

# %% [markdown]
# Humidity is know as atmospheric moisture. We have plotted a graph between temperature and humidity in the given dataset. The graph shows that as the temperature increases the humidity decreases so we can say that increasing temperature decreases the wetness in the atmosphere.

# %%
sns.set(rc = {'figure.figsize':(13,9)})
sns.lineplot(x=df['Press_kPa'],y=df['Temp_C']).set(title='Temperature VS Pressure')
# Out:
# [Text(0.5, 1.0, 'Temperature VS Pressure')]

# %% [markdown]
# The above plot has been plotted between temperature and pressure. It shows that both are inversely proportional. As the pressure is increasing the temperature is decreasing and vice versa.

# %%
sns.set(rc = {'figure.figsize':(13,9)})
x=df['Rel Hum_%'].head(500)
y=df['Visibility_km'].head(500)
sns.barplot(x,y).set(title='Temperature VS Visibility')
# Out:
# C:\Users\hashir\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [Text(0.5, 1.0, 'Temperature VS Visibility')]

# %% [markdown]
# Above graph has been plotted between Humidity and Visibility. It shows that as the Humidity(fog) in an area increases the Visibility decreases.

# %%
sns.pairplot(df)

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## MODEL ##

# %%
from sklearn.preprocessing import LabelEncoder
label=LabelEncoder()
df['Date/Time']=label.fit_transform(df['Date/Time'])
df['Weather']=label.fit_transform(df['Weather'])

# %%
## Spliting x and y 
x=df.iloc[:,:-1]
y=df['Weather']

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.7,test_size=0.3)

# %%
from sklearn.ensemble import RandomForestClassifier

model= RandomForestClassifier(n_estimators=95, criterion = "entropy")

# training
fit=model.fit(x_train, y_train)

#testing
pred=model.predict(x_test)

# %%
model.score(x_train,y_train)
# Out:
# 1.0

# %%
model.score(x_test,y_test)
# Out:
# 0.584597875569044

# %%
sns.distplot(y, hist=False, color="r", label="Actual Value")
sns.distplot(pred, hist=False, color="b", label="Predicted Values" )

plt.title('Actual vs Predicted Values for Price')
plt.legend()
plt.show()
# Out:
# C:\Users\hashir\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\hashir\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,pred)
# Out:
# 0.584597875569044
